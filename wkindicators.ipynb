# %% [markdown]
# # Prototype WK01
# ## Create a data set of pharmacies in Germany

# %% [markdown]
# ### Set-Up

# %%
import sys
# !{sys.executable} -m pip install geopandas
# !{sys.executable} -m pip install shapely
# !{sys.executable} -m pip install geopy
# Out:
# Requirement already satisfied: geopandas in c:\users\haus108\documents\anaconda\lib\site-packages (0.13.2)
# Requirement already satisfied: packaging in c:\users\haus108\documents\anaconda\lib\site-packages (from geopandas) (20.9)
# Requirement already satisfied: pyproj>=3.0.1 in c:\users\haus108\documents\anaconda\lib\site-packages (from geopandas) (3.6.0)
# Requirement already satisfied: shapely>=1.7.1 in c:\users\haus108\documents\anaconda\lib\site-packages (from geopandas) (2.0.1)
# Requirement already satisfied: fiona>=1.8.19 in c:\users\haus108\documents\anaconda\lib\site-packages (from geopandas) (1.9.4.post1)
# Requirement already satisfied: pandas>=1.1.0 in c:\users\haus108\documents\anaconda\lib\site-packages (from geopandas) (1.4.4)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\haus108\documents\anaconda\lib\site-packages (from fiona>=1.8.19->geopandas) (1.1.1)
# Requirement already satisfied: certifi in c:\users\haus108\documents\anaconda\lib\site-packages (from fiona>=1.8.19->geopandas) (2022.9.24)
# Requirement already satisfied: click~=8.0 in c:\users\haus108\documents\anaconda\lib\site-packages (from fiona>=1.8.19->geopandas) (8.0.4)
# Requirement already satisfied: cligj>=0.5 in c:\users\haus108\documents\anaconda\lib\site-packages (from fiona>=1.8.19->geopandas) (0.7.2)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\haus108\documents\anaconda\lib\site-packages (from fiona>=1.8.19->geopandas) (22.1.0)
# Requirement already satisfied: importlib-metadata in c:\users\haus108\documents\anaconda\lib\site-packages (from fiona>=1.8.19->geopandas) (4.13.0)
# Requirement already satisfied: six in c:\users\haus108\documents\anaconda\lib\site-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\haus108\documents\anaconda\lib\site-packages (from pandas>=1.1.0->geopandas) (1.21.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\haus108\documents\anaconda\lib\site-packages (from pandas>=1.1.0->geopandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\haus108\documents\anaconda\lib\site-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\haus108\documents\anaconda\lib\site-packages (from packaging->geopandas) (2.4.7)
# Requirement already satisfied: colorama in c:\users\haus108\documents\anaconda\lib\site-packages (from click~=8.0->fiona>=1.8.19->geopandas) (0.4.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\haus108\documents\anaconda\lib\site-packages (from importlib-metadata->fiona>=1.8.19->geopandas) (3.8.0)
# Requirement already satisfied: shapely in c:\users\haus108\documents\anaconda\lib\site-packages (2.0.1)
# Requirement already satisfied: numpy>=1.14 in c:\users\haus108\documents\anaconda\lib\site-packages (from shapely) (1.21.5)
# Requirement already satisfied: geopy in c:\users\haus108\documents\anaconda\lib\site-packages (2.3.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\haus108\documents\anaconda\lib\site-packages (from geopy) (2.0)

# %%
import requests
import json
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point, shape
import numpy as np
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# %% [markdown]
# ### Get geometry data (here: Open Data API from Wegweiser Kommune)

# %%
headers = {
    'accept': 'application/json',
}

params = {
    'bbox': '5.98865807458,47.3024876979,15.0169958839,54.983104153',
    'layer': 'COMMUNE',
}

response = requests.get(
    'https://www.wegweiser-kommune.de/data-api/rest/map/data/demografische-entwicklung%2Bgeburten%2Bgemeinden-und-staedte%2B2021%2Bkarte',
    params=params,
    headers=headers,
)

# %%
kommune_data = response.json()

# Convert to a geopandas dataframe
kommune_df = gpd.GeoDataFrame.from_features(kommune_data['regions']['features'])

# Create a spatial index
kommune_sindex = kommune_df.sindex

# %%
kommune_df.head()
# Out:
#                                             geometry       gkz  values  \
# 0  MULTIPOLYGON (((11.75800 48.14860, 11.74770 48...  09184118  [12.2]
# 1  MULTIPOLYGON (((8.64860 50.76270, 8.61800 50.7...  06534010   [9.2]
# 2  MULTIPOLYGON (((9.19270 47.97930, 9.19030 47.9...  08437078  [10.9]
# 3  MULTIPOLYGON (((8.00460 50.06550, 7.98850 50.0...  06439014   [8.2]
# 4  MULTIPOLYGON (((8.90720 50.54960, 8.82380 50.5...  06531016  [10.4]
#
#               name classIndices    friendlyUrl      type selected  \
# 0  Feldkirchen (M)          [6]  feldkirchen-m  GEMEINDE     True
# 1       Gladenbach          [4]     gladenbach  GEMEINDE     True
# 2         Meßkirch          [5]      messkirch  GEMEINDE     True
# 3     Schlangenbad          [4]   schlangenbad  GEMEINDE     True
# 4      Reiskirchen          [5]    reiskirchen  GEMEINDE     True
#
#    pharmacy_count
# 0             1.0
# 1             4.0
# 2             2.0
# 3             1.0
# 4             2.0

# %% [markdown]
# ### Get Open Street Maps Data from Overpass API

# %%
# Overpass API URL
overpass_url = "http://www.overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area["ISO3166-1"="DE"];
(
node["amenity"="pharmacy"](area);
way["amenity"="pharmacy"](area);
rel["amenity"="pharmacy"](area);
node["healthcare"="pharmacy"](area);
way["healthcare"="pharmacy"](area);
rel["healthcare"="pharmacy"](area);
);
out center;
"""

# Send the request
response = requests.get(overpass_url, params={'data': overpass_query}) 
data = response.json()

# %%
len(data['elements'])
# Out:
# 16869

# %% [markdown]
# ### Match data

# %%
# Define empty list to hold pharmacy data 
pharmacies = []

# For each pharmacy
for element in data['elements']:
    if element['type'] == 'node':
        lon = element['lon']
        lat = element['lat']
    elif 'center' in element:
        lon = element['center']['lon']
        lat = element['center']['lat']
        
    # Create a point
    point = Point(lon, lat)

    # Get possible matches from the spatial index 
    possible_matches_index = list(kommune_sindex.intersection(point.bounds))
    possible_matches = kommune_df.iloc[possible_matches_index]

    # Check if point is in any of the possible matches 
    precise_matches = possible_matches[possible_matches.intersects(point)]

    # If a match is found
    match = precise_matches.iloc[0]['gkz'] if not precise_matches.empty else None

    pharmacies.append({'lon': lon, 'lat': lat, 'gkz': match})

# Create DataFrame from list
df = pd.DataFrame(pharmacies)

# %%
# Count the pharmacies per kommune
pharmacy_counts = df.groupby('gkz').size().reset_index(name='pharmacy_count')

# Merge the counts with the kommune_df
kommune_df = kommune_df.merge(pharmacy_counts, how='left', on='gkz')

# Fill NaN values with 0
kommune_df['pharmacy_count'] = kommune_df['pharmacy_count'].fillna(0)

print(kommune_df)
# Out:
#                                                geometry       gkz  values  \
# 0     MULTIPOLYGON (((11.75800 48.14860, 11.74770 48...  09184118  [12.2]
# 1     MULTIPOLYGON (((8.64860 50.76270, 8.61800 50.7...  06534010   [9.2]
# 2     MULTIPOLYGON (((9.19270 47.97930, 9.19030 47.9...  08437078  [10.9]
# 3     MULTIPOLYGON (((8.00460 50.06550, 7.98850 50.0...  06439014   [8.2]
# 4     MULTIPOLYGON (((8.90720 50.54960, 8.82380 50.5...  06531016  [10.4]
# ...                                                 ...       ...     ...
# 3057  MULTIPOLYGON (((12.16350 50.95870, 12.09230 50...  15084952   [6.3]
# 3058  MULTIPOLYGON (((11.08350 51.82660, 11.05820 51...  15085951   [4.8]
# 3059  MULTIPOLYGON (((10.96270 51.46030, 10.97270 51...  15087951   [5.6]
# 3060  MULTIPOLYGON (((11.75910 51.28370, 11.70120 51...  15088951   [4.6]
# 3061  MULTIPOLYGON (((11.44610 52.00700, 11.45080 51...  15089951   [5.2]
#
#                          name classIndices               friendlyUrl  \
# 0             Feldkirchen (M)          [6]             feldkirchen-m
# 1                  Gladenbach          [4]                gladenbach
# 2                    Meßkirch          [5]                 messkirch
# 3                Schlangenbad          [4]              schlangenbad
# 4                 Reiskirchen          [5]               reiskirchen
# ...                       ...          ...                       ...
# 3057  Droyßiger-Zeitzer Forst          [2]  droyssiger-zeitzer-forst
# 3058                  Vorharz          [2]                   vorharz
# 3059              Goldene Aue          [2]               goldene-aue
# 3060               Weida-Land          [2]                weida-land
# 3061            Egelner Mulde          [2]             egelner-mulde
#
#           type selected  pharmacy_count
# 0     GEMEINDE     True             1.0
# 1     GEMEINDE     True             4.0
# 2     GEMEINDE     True             2.0
# 3     GEMEINDE     True             1.0
# 4     GEMEINDE     True             2.0
# ...        ...      ...             ...
# 3057  GEMEINDE     True             1.0
# 3058  GEMEINDE     True             2.0
# 3059  GEMEINDE     True             1.0
# 3060  GEMEINDE     True             1.0
# 3061  GEMEINDE     True             2.0
#
# [3062 rows x 9 columns]

# %%
kommune_df.to_csv('data/output/pharmacydata.csv', index=False, sep =";")

# %%
kommune_df.head()
# Out:
#                                             geometry       gkz  values  \
# 0  MULTIPOLYGON (((11.75800 48.14860, 11.74770 48...  09184118  [12.2]
# 1  MULTIPOLYGON (((8.64860 50.76270, 8.61800 50.7...  06534010   [9.2]
# 2  MULTIPOLYGON (((9.19270 47.97930, 9.19030 47.9...  08437078  [10.9]
# 3  MULTIPOLYGON (((8.00460 50.06550, 7.98850 50.0...  06439014   [8.2]
# 4  MULTIPOLYGON (((8.90720 50.54960, 8.82380 50.5...  06531016  [10.4]
#
#               name classIndices    friendlyUrl      type selected  \
# 0  Feldkirchen (M)          [6]  feldkirchen-m  GEMEINDE     True
# 1       Gladenbach          [4]     gladenbach  GEMEINDE     True
# 2         Meßkirch          [5]      messkirch  GEMEINDE     True
# 3     Schlangenbad          [4]   schlangenbad  GEMEINDE     True
# 4      Reiskirchen          [5]    reiskirchen  GEMEINDE     True
#
#    pharmacy_count
# 0             1.0
# 1             4.0
# 2             2.0
# 3             1.0
# 4             2.0

# %%
kommune_df['gkz']=kommune_df['gkz'].astype(str)

# %% [markdown]
# ### Quality Assurance

# %%
# tabelle: gkz, name, count pharmacies

# %%
# qc-datei: stichprobe an apotheken -> geompoints (google)

# %%
qc_data = pd.read_excel("data/qc_apothekenregisterstichprobe.xlsx", sheet_name = "Values", dtype = {'gkz': str})

# %%
qc_data.head()
# Out:
#         gkz  GKZ Ordnen           ARS              Name  \
# 0  08236076     8236076   82365002076  Königsbach-Stein
# 1  08415059     8415059   84150059059        Pfullingen
# 2  14628110    14628110  146280110110           Freital
# 3  13074026    13074026  130740026026      Grevesmühlen
# 4  05566068     5566068   55660068068           Ochtrup
#
#                         Ausgabe im Wegweiser Kommune  \
# 0                     Königsbach-Stein (im Enzkreis)
# 1               Pfullingen (im Landkreis Reutlingen)
# 2  Freital (im Landkreis Sächsische Schweiz-Oster...
# 3    Grevesmühlen (im Landkreis Nordwestmecklenburg)
# 4                   Ochtrup (im Landkreis Steinfurt)
#
#                            typ_bezeichnung   auswahl    plz  anzahl apotheken  \
# 0  Gemeinde mit 5.000 oder mehr Einwohnern  0.999521  75203               3.0
# 1  Gemeinde mit 5.000 oder mehr Einwohnern  0.999435  72793               6.0
# 2  Gemeinde mit 5.000 oder mehr Einwohnern  0.999347  01705               8.0
# 3  Gemeinde mit 5.000 oder mehr Einwohnern  0.999173  23936               4.0
# 4  Gemeinde mit 5.000 oder mehr Einwohnern  0.999123  48607               5.0
#
#                     notiz
# 0                     NaN
# 1                     NaN
# 2  pesterwitz zu freital?
# 3                     NaN
# 4                     NaN

# %%
qc_df = qc_data.merge(kommune_df, on = "gkz")[['gkz', 'name', 'anzahl apotheken', 'pharmacy_count']]

# %%
qc_df['true'] = qc_df['pharmacy_count'] == qc_df['anzahl apotheken']
qc_df['percentage'] = qc_df['pharmacy_count']/qc_df['anzahl apotheken']

# %%
qc_df[qc_df['percentage'] > 1]
# Out:
#          gkz                 name  anzahl apotheken  pharmacy_count   true  \
# 8   10044111     Dillingen / Saar               8.0            11.0  False
# 12  05970024             Kreuztal               3.0             6.0  False
# 27  15091241  Oranienbaum-Wörlitz               2.0             3.0  False
# 35  07235907           Trier-Land               1.0             2.0  False
# 39  06534021      Wetter (Hessen)               2.0             3.0  False
# 49  15083953          Obere Aller               3.0             5.0  False
# 52  14521260   Grünhain-Beierfeld               1.0             2.0  False
# 58  13075136          Ueckermünde               3.0             4.0  False
# 62  05158032              Velbert              19.0            20.0  False
# 63  03458014         Wildeshausen               4.0             5.0  False
# 70  08426070             Laupheim               4.0             5.0  False
# 71  05974016              Erwitte               2.0             3.0  False
# 78  07138905            Puderbach               1.0             2.0  False
# 79  12064512              Wriezen               2.0             4.0  False
# 82  07339903        Gau-Algesheim               2.0             4.0  False
#
#     percentage
# 8     1.375000
# 12    2.000000
# 27    1.500000
# 35    2.000000
# 39    1.500000
# 49    1.666667
# 52    2.000000
# 58    1.333333
# 62    1.052632
# 63    1.250000
# 70    1.250000
# 71    1.500000
# 78    2.000000
# 79    2.000000
# 82    2.000000

# %%
qc_df[qc_df['percentage'] < 1]
# Out:
#          gkz                    name  anzahl apotheken  pharmacy_count   true  \
# 1   08415059              Pfullingen               6.0             5.0  False
# 7   03454018             Haren (Ems)               9.0             6.0  False
# 10  03459403               Fürstenau               3.0             2.0  False
# 15  06533004                Dornburg               2.0             1.0  False
# 16  09189157               Trostberg               2.0             1.0  False
# 18  05154012                 Geldern               9.0             8.0  False
# 19  08125102               Weinsberg               3.0             2.0  False
# 22  08337123            Wutöschingen               1.0             0.0  False
# 26  03453002                   Bösel               2.0             1.0  False
# 30  03356009             Schwanewede               3.0             2.0  False
# 32  05170032               Rheinberg               6.0             5.0  False
# 36  06533009     Limburg an der Lahn              11.0            10.0  False
# 40  09571214         Wassertrüdingen               2.0             1.0  False
# 41  09174122           Hebertshausen               2.0             0.0  False
# 44  09179126              Gröbenzell               5.0             4.0  False
# 47  14523120  Falkenstein / Vogtland               4.0             2.0  False
# 50  16072013      Neuhaus am Rennweg               5.0             3.0  False
# 51  06634002               Edermünde               1.0             0.0  False
# 53  15088065             Braunsbedra               2.0             1.0  False
# 55  03461003             Butjadingen               1.0             0.0  False
# 56  10041516             Quierschied               3.0             0.0  False
# 59  07339030      Ingelheim am Rhein               5.0             4.0  False
# 60  05758024                   Löhne               8.0             6.0  False
# 61  03352011          Cuxhaven (CUX)              11.0            10.0  False
# 67  08136021           Essingen (AA)               3.0             2.0  False
# 68  05570024             Everswinkel               1.0             0.0  False
# 72  09572158              Uttenreuth               2.0             1.0  False
# 73  15082340      Sandersdorf-Brehna               4.0             3.0  False
# 74  01055032    Neustadt in Holstein               4.0             0.0  False
# 80  06435009             Freigericht               4.0             3.0  False
# 84  09375148                   Hemau               2.0             1.0  False
#
#     percentage
# 1     0.833333
# 7     0.666667
# 10    0.666667
# 15    0.500000
# 16    0.500000
# 18    0.888889
# 19    0.666667
# 22    0.000000
# 26    0.500000
# 30    0.666667
# 32    0.833333
# 36    0.909091
# 40    0.500000
# 41    0.000000
# 44    0.800000
# 47    0.500000
# 50    0.600000
# 51    0.000000
# 53    0.500000
# 55    0.000000
# 56    0.000000
# 59    0.800000
# 60    0.750000
# 61    0.909091
# 67    0.666667
# 68    0.000000
# 72    0.500000
# 73    0.750000
# 74    0.000000
# 80    0.750000
# 84    0.500000

# %%
qc_df[qc_df['percentage'] == 1]
# Out:
#          gkz                  name  anzahl apotheken  pharmacy_count  true  \
# 0   08236076      Königsbach-Stein               3.0             3.0  True
# 2   14628110               Freital               8.0             8.0  True
# 3   13074026          Grevesmühlen               4.0             4.0  True
# 4   05566068               Ochtrup               5.0             5.0  True
# 5   06633003              Baunatal               7.0             7.0  True
# 6   05570012                Beelen               1.0             1.0  True
# 9   03356007  Osterholz-Scharmbeck               6.0             6.0  True
# 11  05962048             Neuenrade               1.0             1.0  True
# 14  14521640                  Thum               1.0             1.0  True
# 17  09189145             Siegsdorf               2.0             2.0  True
# 20  10044123         Ensdorf (SLS)               1.0             1.0  True
# 21  16074094             Stadtroda               2.0             2.0  True
# 23  08415073        Trochtelfingen               2.0             2.0  True
# 24  09471145             Hirschaid               3.0             3.0  True
# 25  13072029           Dummerstorf               1.0             1.0  True
# 28  09375118          Beratzhausen               1.0             1.0  True
# 29  12069306        Kloster Lehnin               2.0             2.0  True
# 33  08226068             Reilingen               2.0             2.0  True
# 34  09376151         Oberviechtach               2.0             2.0  True
# 38  10044121          Wallerfangen               2.0             2.0  True
# 42  09679185            Rottendorf               1.0             1.0  True
# 43  09772200         Schwabmünchen               4.0             4.0  True
# 46  09189154             Traunreut               5.0             5.0  True
# 48  14729190             Großpösna               1.0             1.0  True
# 54  08317026             Ettenheim               2.0             2.0  True
# 57  08437086               Ostrach               1.0             1.0  True
# 64  08127063          Obersontheim               1.0             1.0  True
# 65  08436083     Wilhelmsdorf (RV)               1.0             1.0  True
# 66  08435035          Meckenbeuren               2.0             2.0  True
# 69  08325072            Deißlingen               1.0             1.0  True
# 75  09573134              Zirndorf               4.0             4.0  True
# 76  14730230               Oschatz               5.0             5.0  True
# 77  08415053             Münsingen               3.0             3.0  True
# 81  06436009               Kriftel               3.0             3.0  True
# 83  09677114        Arnstein (MSP)               1.0             1.0  True
# 85  06431004              Birkenau               2.0             2.0  True
# 86  09189114              Chieming               1.0             1.0  True
# 87  03357041              Scheeßel               3.0             3.0  True
#
#     percentage
# 0          1.0
# 2          1.0
# 3          1.0
# 4          1.0
# 5          1.0
# 6          1.0
# 9          1.0
# 11         1.0
# 14         1.0
# 17         1.0
# 20         1.0
# 21         1.0
# 23         1.0
# 24         1.0
# 25         1.0
# 28         1.0
# 29         1.0
# 33         1.0
# 34         1.0
# 38         1.0
# 42         1.0
# 43         1.0
# 46         1.0
# 48         1.0
# 54         1.0
# 57         1.0
# 64         1.0
# 65         1.0
# 66         1.0
# 69         1.0
# 75         1.0
# 76         1.0
# 77         1.0
# 81         1.0
# 83         1.0
# 85         1.0
# 86         1.0
# 87         1.0

# %%
qc_df['percentage'].describe()
# Out:
# count    84.000000
# mean      0.935532
# std       0.456444
# min       0.000000
# 25%       0.729167
# 50%       1.000000
# 75%       1.000000
# max       2.000000
# Name: percentage, dtype: float64

# %%
sum(qc_df['true'])/len(qc_df)
# Out:
# 0.4659090909090909

# %%
len(qc_df['true'])
# Out:
# 88

# %%
qc_df.to_csv('data/output/qcresultsdata.csv', index=False, sep =";")

# %% [markdown]
# Questions:
# - Issue of geographical mapping and matching?
#     - Test 1: Check OSM data for wrong matches directly
# - Issue of data quality?
#     - Data enrichment
#     - Use of Google Maps API

# %% [markdown]
# ### Data enrichtment: Handelsregisterdaten

# %% [markdown]
# https://offeneregister.de/daten/

# %%
import sqlite3

def get_table_structure(cursor, table_name):
    cursor.execute(f"PRAGMA table_info({table_name})")
    return cursor.fetchall()

conn = sqlite3.connect('data/handelsregister.db')

c = conn.cursor()

c.execute("SELECT name FROM sqlite_master WHERE type = 'table';")

tables = c.fetchall()

for table in tables:
    print(f"Table: {table[0]}")
    structure = get_table_structure(c, table[0])
    for column in structure:
        print(column)
# Out:
# Table: name
# (0, 'id', 'INTEGER', 1, None, 1)
# (1, 'company_name', 'TEXT', 0, None, 0)
# (2, 'company_id', 'TEXT', 0, None, 0)
# Table: registrations
# (0, 'id', 'INTEGER', 1, None, 1)
# (1, 'confidence', 'TEXT', 0, None, 0)
# (2, 'data_type', 'TEXT', 0, None, 0)
# (3, 'publication_date', 'TEXT', 0, None, 0)
# (4, 'retrieved_at', 'TEXT', 0, None, 0)
# (5, 'source_url', 'TEXT', 0, None, 0)
# (6, 'start_date', 'TEXT', 0, None, 0)
# (7, 'start_date_type', 'TEXT', 0, None, 0)
# (8, 'subsequent_registration_start_date', 'TEXT', 0, None, 0)
# (9, 'company_id', 'TEXT', 0, None, 0)
# (10, 'previous_company_number', 'TEXT', 0, None, 0)
# (11, 'previous_jurisdiction_code', 'TEXT', 0, None, 0)
# (12, 'previous_entity_type', 'TEXT', 0, None, 0)
# (13, 'subsequent_company_number', 'TEXT', 0, None, 0)
# (14, 'subsequent_jurisdiction_code', 'TEXT', 0, None, 0)
# (15, 'subsequent_entity_type', 'TEXT', 0, None, 0)
# (16, 'sample_date', 'TEXT', 0, None, 0)
# (17, 'alternate_company_number', 'TEXT', 0, None, 0)
# (18, 'alternate_jurisdiction_code', 'TEXT', 0, None, 0)
# (19, 'alternate_entity_type', 'TEXT', 0, None, 0)
# (20, 'previous_registration_end_date', 'TEXT', 0, None, 0)
# Table: officer
# (0, 'id', 'INTEGER', 1, None, 1)
# (1, 'name', 'TEXT', 0, None, 0)
# (2, 'position', 'TEXT', 0, None, 0)
# (3, 'start_date', 'TEXT', 0, None, 0)
# (4, 'type', 'TEXT', 0, None, 0)
# (5, 'company_id', 'TEXT', 0, None, 0)
# (6, 'city', 'TEXT', 0, None, 0)
# (7, 'firstname', 'TEXT', 0, None, 0)
# (8, 'flag', 'TEXT', 0, None, 0)
# (9, 'lastname', 'TEXT', 0, None, 0)
# (10, 'title', 'TEXT', 0, None, 0)
# (11, 'dismissed', 'TEXT', 0, None, 0)
# (12, 'end_date', 'TEXT', 0, None, 0)
# (13, 'maidenname', 'TEXT', 0, None, 0)
# (14, 'reference_no', 'TEXT', 0, None, 0)
# Table: company
# (0, 'id', 'INTEGER', 1, None, 1)
# (1, 'company_number', 'TEXT', 0, None, 0)
# (2, 'current_status', 'TEXT', 0, None, 0)
# (3, 'jurisdiction_code', 'TEXT', 0, None, 0)
# (4, 'name', 'TEXT', 0, None, 0)
# (5, 'registered_address', 'TEXT', 0, None, 0)
# (6, 'retrieved_at', 'TEXT', 0, None, 0)
# (7, 'register_flag_AD', 'BOOLEAN', 0, None, 0)
# (8, 'register_flag_CD', 'BOOLEAN', 0, None, 0)
# (9, 'register_flag_DK', 'BOOLEAN', 0, None, 0)
# (10, 'register_flag_HD', 'BOOLEAN', 0, None, 0)
# (11, 'register_flag_SI', 'BOOLEAN', 0, None, 0)
# (12, 'register_flag_UT', 'BOOLEAN', 0, None, 0)
# (13, 'register_flag_VOE', 'BOOLEAN', 0, None, 0)
# (14, 'federal_state', 'TEXT', 0, None, 0)
# (15, 'native_company_number', 'TEXT', 0, None, 0)
# (16, 'registered_office', 'TEXT', 0, None, 0)
# (17, 'registrar', 'TEXT', 0, None, 0)
# (18, 'register_art', 'TEXT', 0, None, 0)
# (19, 'register_nummer', 'TEXT', 0, None, 0)
# (20, 'former_registrar', 'TEXT', 0, None, 0)
# (21, 'register_flag_', 'TEXT', 0, None, 0)
# (22, 'register_flag_Note:', 'TEXT', 0, None, 0)
# (23, '_registerNummerSuffix', 'TEXT', 0, None, 0)
# (24, 'register_flag_Status information', 'TEXT', 0, None, 0)
# Table: company_fts
# (0, 'name', '', 0, None, 0)
# (1, 'registered_address', '', 0, None, 0)
# Table: company_fts_data
# (0, 'id', 'INTEGER', 0, None, 1)
# (1, 'block', 'BLOB', 0, None, 0)
# Table: company_fts_idx
# (0, 'segid', '', 1, None, 1)
# (1, 'term', '', 1, None, 2)
# (2, 'pgno', '', 0, None, 0)
# Table: company_fts_docsize
# (0, 'id', 'INTEGER', 0, None, 1)
# (1, 'sz', 'BLOB', 0, None, 0)
# Table: company_fts_config
# (0, 'k', '', 1, None, 1)
# (1, 'v', '', 0, None, 0)
# Table: officer_fts
# (0, 'name', '', 0, None, 0)
# Table: officer_fts_data
# (0, 'id', 'INTEGER', 0, None, 1)
# (1, 'block', 'BLOB', 0, None, 0)
# Table: officer_fts_idx
# (0, 'segid', '', 1, None, 1)
# (1, 'term', '', 1, None, 2)
# (2, 'pgno', '', 0, None, 0)
# Table: officer_fts_docsize
# (0, 'id', 'INTEGER', 0, None, 1)
# (1, 'sz', 'BLOB', 0, None, 0)
# Table: officer_fts_config
# (0, 'k', '', 1, None, 1)
# (1, 'v', '', 0, None, 0)
# Table: name_fts
# (0, 'company_name', '', 0, None, 0)
# Table: name_fts_data
# (0, 'id', 'INTEGER', 0, None, 1)
# (1, 'block', 'BLOB', 0, None, 0)
# Table: name_fts_idx
# (0, 'segid', '', 1, None, 1)
# (1, 'term', '', 1, None, 2)
# (2, 'pgno', '', 0, None, 0)
# Table: name_fts_docsize
# (0, 'id', 'INTEGER', 0, None, 1)
# (1, 'sz', 'BLOB', 0, None, 0)
# Table: name_fts_config
# (0, 'k', '', 1, None, 1)
# (1, 'v', '', 0, None, 0)

# %%
# select entries from table: company with columns id, name and registered_address: Germany has approx. 17,000 pharmacies
registry_df = pd.read_sql_query('SELECT * FROM company WHERE name LIKE "%Apotheke%"', conn)
print(len(registry_df))
registry_df.head()
# Out:
# 33838
#      id   company_number        current_status jurisdiction_code  \
# 0   576   R1101_HRA17543               removed                de
# 1   786  F1103R_HRA38448  currently registered                de
# 2  1007    M1103_HRB3094  currently registered                de
# 3  1453   M1201_HRA49032  currently registered                de
# 4  1971     U1206_HRA658  currently registered                de
#
#                                                 name  \
# 0                  Linden-Apotheke Georg Reibel e.K.
# 1                        Apotheke in Nikolassee e.K.
# 2         CIDA Computerleistungen für Apotheken GmbH
# 3                 Westend Apotheke Homira Alavi e.K.
# 4  Löwen-Apotheke Apothekerin Constanze Köhler, e.K.
#
#                                registered_address          retrieved_at  \
# 0                                            None  2018-07-25T13:02:09Z
# 1                                            None  2018-11-09T18:29:04Z
# 2                                            None  2018-06-22T05:25:39Z
# 3    Brentano Straße 29, 60325 Frankfurt am Main.  2018-07-25T13:36:39Z
# 4  Erich-Kästner-Straße 32, 09669 Frankenberg/Sa.  2018-11-09T10:12:34Z
#
#    register_flag_AD  register_flag_CD  register_flag_DK  ...  \
# 0                 0                 1                 1  ...
# 1                 1                 1                 1  ...
# 2                 1                 1                 1  ...
# 3                 1                 1                 1  ...
# 4                 1                 1                 1  ...
#
#                native_company_number  registered_office  \
# 0               Düsseldorf HRA 17543             Hilden
# 1  Berlin (Charlottenburg) HRA 38448             Berlin
# 2                 Darmstadt HRB 3094          Darmstadt
# 3        Frankfurt am Main HRA 49032  Frankfurt am Main
# 4                   Chemnitz HRA 658    Frankenberg/Sa.
#
#                  registrar  register_art register_nummer former_registrar  \
# 0               Düsseldorf           HRA           17543             None
# 1  Berlin (Charlottenburg)           HRA           38448             None
# 2                Darmstadt           HRB            3094             None
# 3        Frankfurt am Main           HRA           49032             None
# 4                 Chemnitz           HRA             658             None
#
#   register_flag_ register_flag_Note: _registerNummerSuffix  \
# 0           None                None                  None
# 1           None                None                  None
# 2           None                None                  None
# 3           None                None                  None
# 4           None                None                  None
#
#   register_flag_Status information
# 0                             None
# 1                             None
# 2                             None
# 3                             None
# 4                             None
#
# [5 rows x 25 columns]

# %%
# Drop duplicates
registry_df = registry_df.drop_duplicates(subset = ['register_nummer', 'register_art'], keep = 'last').reset_index(drop = True)
len(registry_df)
# Out:
# 21819

# %%
# filter actice pharmacies - are hrb entries relevant?
registry_df = registry_df.loc[(registry_df['current_status'] == "currently registered") & (registry_df['register_art'] == "HRA")]
print(len(registry_df))
registry_df.head()
# Out:
# 11384
#      id   company_number        current_status jurisdiction_code  \
# 1   786  F1103R_HRA38448  currently registered                de
# 3  1453   M1201_HRA49032  currently registered                de
# 5  2541    R1402_HRA5334  currently registered                de
# 6  2817  B8535_HRA440044  currently registered                de
# 7  2989  B8535_HRA340724  currently registered                de
#
#                                                 name  \
# 1                        Apotheke in Nikolassee e.K.
# 3                 Westend Apotheke Homira Alavi e.K.
# 5             Bären-Apotheke, Inh.: Olaf Orthen e.K.
# 6  Apotheke Billigheim Wolfgang Pretzsch-Eckhard,...
# 7                    Stadt-Apotheke Volker Blum e.K.
#
#                              registered_address          retrieved_at  \
# 1                                          None  2018-11-09T18:29:04Z
# 3  Brentano Straße 29, 60325 Frankfurt am Main.  2018-07-25T13:36:39Z
# 5                                          None  2018-07-25T14:18:03Z
# 6                                          None  2018-11-09T09:59:11Z
# 7                                          None  2018-11-09T09:58:28Z
#
#    register_flag_AD  register_flag_CD  register_flag_DK  ...  \
# 1                 1                 1                 1  ...
# 3                 1                 1                 1  ...
# 5                 1                 1                 1  ...
# 6                 1                 1                 1  ...
# 7                 1                 1                 1  ...
#
#                native_company_number  registered_office  \
# 1  Berlin (Charlottenburg) HRA 38448             Berlin
# 3        Frankfurt am Main HRA 49032  Frankfurt am Main
# 5                   Krefeld HRA 5334             Kempen
# 6                Mannheim HRA 440044         Billigheim
# 7                Mannheim HRA 340724           Sinsheim
#
#                  registrar  register_art register_nummer former_registrar  \
# 1  Berlin (Charlottenburg)           HRA           38448             None
# 3        Frankfurt am Main           HRA           49032             None
# 5                  Krefeld           HRA            5334             None
# 6                 Mannheim           HRA          440044             None
# 7                 Mannheim           HRA          340724             None
#
#   register_flag_ register_flag_Note: _registerNummerSuffix  \
# 1           None                None                  None
# 3           None                None                  None
# 5           None                None                  None
# 6           None                None                  None
# 7           None                None                  None
#
#   register_flag_Status information
# 1                             None
# 3                             None
# 5                             None
# 6                             None
# 7                             None
#
# [5 rows x 25 columns]

# %%
registry_df['searchable_address'] = registry_df['registered_address'] + ' ' + registry_df['registered_office']

# %%
registry_df.head()
# Out:
#      id   company_number        current_status jurisdiction_code  \
# 1   786  F1103R_HRA38448  currently registered                de
# 3  1453   M1201_HRA49032  currently registered                de
# 5  2541    R1402_HRA5334  currently registered                de
# 6  2817  B8535_HRA440044  currently registered                de
# 7  2989  B8535_HRA340724  currently registered                de
#
#                                                 name  \
# 1                        Apotheke in Nikolassee e.K.
# 3                 Westend Apotheke Homira Alavi e.K.
# 5             Bären-Apotheke, Inh.: Olaf Orthen e.K.
# 6  Apotheke Billigheim Wolfgang Pretzsch-Eckhard,...
# 7                    Stadt-Apotheke Volker Blum e.K.
#
#                              registered_address          retrieved_at  \
# 1                                          None  2018-11-09T18:29:04Z
# 3  Brentano Straße 29, 60325 Frankfurt am Main.  2018-07-25T13:36:39Z
# 5                                          None  2018-07-25T14:18:03Z
# 6                                          None  2018-11-09T09:59:11Z
# 7                                          None  2018-11-09T09:58:28Z
#
#    register_flag_AD  register_flag_CD  register_flag_DK  ...  \
# 1                 1                 1                 1  ...
# 3                 1                 1                 1  ...
# 5                 1                 1                 1  ...
# 6                 1                 1                 1  ...
# 7                 1                 1                 1  ...
#
#    registered_office                registrar  register_art  register_nummer  \
# 1             Berlin  Berlin (Charlottenburg)           HRA            38448
# 3  Frankfurt am Main        Frankfurt am Main           HRA            49032
# 5             Kempen                  Krefeld           HRA             5334
# 6         Billigheim                 Mannheim           HRA           440044
# 7           Sinsheim                 Mannheim           HRA           340724
#
#   former_registrar register_flag_ register_flag_Note: _registerNummerSuffix  \
# 1             None           None                None                  None
# 3             None           None                None                  None
# 5             None           None                None                  None
# 6             None           None                None                  None
# 7             None           None                None                  None
#
#   register_flag_Status information  \
# 1                             None
# 3                             None
# 5                             None
# 6                             None
# 7                             None
#
#                                   searchable_address
# 1                                                NaN
# 3  Brentano Straße 29, 60325 Frankfurt am Main. F...
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
#
# [5 rows x 26 columns]

# %%
# Get geometry for registry data (https://geopy.readthedocs.io/en/stable/)
geolocator = Nominatim(user_agent="example app")
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=3)
registry_df["loc"] = registry_df["searchable_address"].apply(geolocator.geocode)
registry_df["point"]= registry_df["loc"].apply(lambda loc: tuple(loc.point) if loc else None)
registry_df[['lat', 'lon', 'altitude']] = pd.DataFrame(registry_df['point'].to_list(), index=df.index)
registry_df
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~\Documents\Anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\Documents\Anaconda\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Documents\Anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#
# ~\Documents\Anaconda\lib\http\client.py in getresponse(self)
#    1376             try:
# -> 1377                 response.begin()
#    1378             except ConnectionError:
#
# ~\Documents\Anaconda\lib\http\client.py in begin(self)
#     319         while True:
# --> 320             version, status, reason = self._read_status()
#     321             if status != CONTINUE:
#
# ~\Documents\Anaconda\lib\http\client.py in _read_status(self)
#     280     def _read_status(self):
# --> 281         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282         if len(line) > _MAXLINE:
#
# ~\Documents\Anaconda\lib\socket.py in readinto(self, b)
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#
# ~\Documents\Anaconda\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1241                   self.__class__)
# -> 1242             return self.read(nbytes, buffer)
#    1243         else:
#
# ~\Documents\Anaconda\lib\ssl.py in read(self, len, buffer)
#    1099             if buffer is not None:
# -> 1100                 return self._sslobj.read(len, buffer)
#    1101             else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# ~\Documents\Anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#
# ~\Documents\Anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
# --> 451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     452             raise
#
# ~\Documents\Anaconda\lib\site-packages\urllib3\connectionpool.py in _raise_timeout(self, err, url, timeout_value)
#     339         if isinstance(err, SocketTimeout):
# --> 340             raise ReadTimeoutError(
#     341                 self, url, "Read timed out. (read timeout=%s)" % timeout_value
#
# ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\Documents\Anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     488             if not chunked:
# --> 489                 resp = conn.urlopen(
#     490                     method=request.method,
#
# ~\Documents\Anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     814             )
# --> 815             return self.urlopen(
#     816                 method,
#
# ~\Documents\Anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     814             )
# --> 815             return self.urlopen(
#     816                 method,
#
# ~\Documents\Anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     786
# --> 787             retries = retries.increment(
#     788                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~\Documents\Anaconda\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     591         if new_retry.is_exhausted():
# --> 592             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     593
#
# MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Str.+Oppach&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~\Documents\Anaconda\lib\site-packages\geopy\adapters.py in _request(self, url, timeout, headers)
#     456         try:
# --> 457             resp = self.session.get(url, timeout=timeout, headers=headers)
#     458         except Exception as error:
#
# ~\Documents\Anaconda\lib\site-packages\requests\sessions.py in get(self, url, **kwargs)
#     599         kwargs.setdefault("allow_redirects", True)
# --> 600         return self.request("GET", url, **kwargs)
#     601
#
# ~\Documents\Anaconda\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#
# ~\Documents\Anaconda\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#
# ~\Documents\Anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     564
# --> 565             raise ConnectionError(e, request=request)
#     566
#
# ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Str.+Oppach&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# GeocoderUnavailable                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_59272\2565484375.py in <module>
#       2 geolocator = Nominatim(user_agent="example app")
#       3 geocode = RateLimiter(geolocator.geocode, min_delay_seconds=3)
# ----> 4 registry_df["loc"] = registry_df["searchable_address"].apply(geolocator.geocode)
#       5 registry_df["point"]= registry_df["loc"].apply(lambda loc: tuple(loc.point) if loc else None)
#       6 registry_df[['lat', 'lon', 'altitude']] = pd.DataFrame(registry_df['point'].to_list(), index=df.index)
#
# ~\Documents\Anaconda\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4431         dtype: float64
#    4432         """
# -> 4433         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4434
#    4435     def _reduce(
#
# ~\Documents\Anaconda\lib\site-packages\pandas\core\apply.py in apply(self)
#    1086             return self.apply_str()
#    1087
# -> 1088         return self.apply_standard()
#    1089
#    1090     def agg(self):
#
# ~\Documents\Anaconda\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1141                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1142                 # "Callable[[Any], Any]"
# -> 1143                 mapped = lib.map_infer(
#    1144                     values,
#    1145                     f,  # type: ignore[arg-type]
#
# ~\Documents\Anaconda\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\Documents\Anaconda\lib\site-packages\geopy\geocoders\nominatim.py in geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded, featuretype, namedetails)
#     295         logger.debug("%s.geocode: %s", self.__class__.__name__, url)
#     296         callback = partial(self._parse_json, exactly_one=exactly_one)
# --> 297         return self._call_geocoder(url, callback, timeout=timeout)
#     298
#     299     def reverse(
#
# ~\Documents\Anaconda\lib\site-packages\geopy\geocoders\base.py in _call_geocoder(self, url, callback, timeout, is_json, headers)
#     366         try:
#     367             if is_json:
# --> 368                 result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     369             else:
#     370                 result = self.adapter.get_text(url, timeout=timeout, headers=req_headers)
#
# ~\Documents\Anaconda\lib\site-packages\geopy\adapters.py in get_json(self, url, timeout, headers)
#     445
#     446     def get_json(self, url, *, timeout, headers):
# --> 447         resp = self._request(url, timeout=timeout, headers=headers)
#     448         try:
#     449             return resp.json()
#
# ~\Documents\Anaconda\lib\site-packages\geopy\adapters.py in _request(self, url, timeout, headers)
#     467                     raise GeocoderServiceError(message)
#     468                 else:
# --> 469                     raise GeocoderUnavailable(message)
#     470             elif isinstance(error, requests.Timeout):
#     471                 raise GeocoderTimedOut("Service timed out")
#
# GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Str.+Oppach&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))

# %%
conn.close()

# %% [markdown]
# ### Playground

# %%
# Error catching - no all addresses are conclusive
def augment(x):
    try:
        return x.geolocator.geocode()
    except:
        return 'error:' + str(x)

test["loc"] = test["registered_address"].apply(lambda x: augment(x))

# %%
test['registered_address'].str.contains('Hauptstr.')
